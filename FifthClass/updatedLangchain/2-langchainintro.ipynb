# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]= os.getenv('GROQ_API_KEY')

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("llama-3.1-8b-instant", model_provider="groq")

print(model)
# Out:
# output_version=None profile={'max_input_tokens': 131072, 'max_output_tokens': 8192, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True} client=<groq.resources.chat.completions.Completions object at 0x000001C6D509D890> async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001C6D509ED50> model_name='llama-3.1-8b-instant' model_kwargs={} groq_api_key=SecretStr('**********') groq_api_base=None groq_proxy=None

# %%
response= model.invoke("hello how are you")
response
# Out:
# AIMessage(content="Hello. I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you have. How can I help you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 47, 'prompt_tokens': 39, 'total_tokens': 86, 'completion_time': 0.06147939, 'completion_tokens_details': None, 'prompt_time': 0.002577809, 'prompt_tokens_details': None, 'queue_time': 0.159554129, 'total_time': 0.064057199}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e72d6-583b-7193-b267-ba824315249a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 47, 'total_tokens': 86})

# %%
from langchain_groq import ChatGroq

model= ChatGroq(model="llama-3.1-8b-instant")
response= model.invoke("hello do you know the name of my dog")
response
# Out:
# AIMessage(content="I'm happy to chat with you, but I don't actually know the name of your dog. This is the beginning of our conversation, and I don't have any prior information about you or your pet. Would you like to tell me about your furry friend? I'd love to hear about them!", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 44, 'total_tokens': 106, 'completion_time': 0.082312263, 'completion_tokens_details': None, 'prompt_time': 0.00714688, 'prompt_tokens_details': None, 'queue_time': 0.215405388, 'total_time': 0.089459143}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_4387d3edbb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e72d9-1303-7783-b88a-32cbb1cc5fb8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 62, 'total_tokens': 106})

# %%
for chunk in model.stream("write me a 200 words paragrapht on AI"):
    print(chunk.text, end=" ", flush=True)
# Out:
#  The  advent  of  Artificial  Intelligence  ( AI )  has  revolution ized  the  way  we  live ,  work ,  and  interact  with  one  another .  At  its  core ,  AI  refers  to  the  development  of  computer  systems  that  can  perform  tasks  that  typically  require  human  intelligence ,  such  as  learning ,  problem -solving ,  and  decision -making .  This  cutting -edge  technology  has  enabled  machines  to  process  vast  amounts  of  data ,  recognize  patterns ,  and  make  predictions  with  unprecedented  accuracy .  From  virtual  assistants  like  Siri  and  Alexa  to  self -driving  cars  and  personalized  product  recommendations ,  AI  has  become  an  integral  part  of  our  daily  lives .
#
#  As  AI  continues  to  advance ,  its  applications  are  expanding  into  sectors  such  as  healthcare ,  finance ,  and  education .  For  instance ,  AI -powered  algorithms  can  help  diagnose  diseases  more  accurately  and  quickly ,  while  machine  learning  models  can  analyze  vast  amounts  of  financial  data  to  identify  potential  risks  and  opportunities .  Furthermore ,  AI -powered  chat bots  and  virtual  learning  platforms  are  transforming  the  way  we  learn  and  interact  with  educational  content .  While  AI  holds  tremendous  promise ,  it  also  raises  important  questions  about  job  displacement ,  data  privacy ,  and  the  ethics  of  creating  intelligent  machines .  As  AI  continues  to  evolve ,  it  is  crucial  that  we  develop  a  deeper  understanding  of  its  capabilities  and  limitations ,  and  work  towards  ensuring  that  its  benefits  are  shared  equ itably  by  all .

# %%
responses= model.batch([
    'why do parrots have colorful feathers',
    'who is pm of india',
    'give me the of cricketers'
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers due to a combination of genetic and environmental factors. Here are some reasons why:\n\n1. **Attracting Mates and Deterrents**: In the wild, bright colors serve as a visual signal to attract potential mates and indicate an individual's health, fertility, and social status. Bright colors can also deter predators and rival parrots, as they may perceive the bird as more aggressive or toxic.\n2. **Camouflage and Adaptation**: While it may seem counterintuitive, some parrot species have evolved to have brightly colored feathers in order to blend in with their surroundings. For example, many tropical parrots have bright colors that help them to blend in with the vibrant foliage of their rainforest habitats.\n3. **Communication and Social Signaling**: Parrots use color to communicate and signal their intentions, emotions, and social status. For example, some parrots will display bright colors during courtship or to signal aggression.\n4. **Evolutionary Pressure**: In the wild, parrots with bright colors may have an advantage over those with duller plumage. This is because bright colors can be an indicator of genetic quality, and individuals with bright colors may be more attractive to potential mates or more effective at defending their territory.\n5. **Genetic Predisposition**: Parrots have a unique genetic makeup that allows them to produce a wide range of colors. The genetics of color production in parrots involve multiple genes that interact to produce the various hues and shades.\n6. **Melanin and Carotenoids**: Parrots have two types of pigments that contribute to their coloration: melanin and carotenoids. Melanin is responsible for black and brown colors, while carotenoids produce yellow, orange, and red colors.\n7. **Environmental Influences**: Environmental factors, such as diet and exposure to sunlight, can also influence the coloration of parrots. For example, some parrots may develop bright colors as a result of consuming carotenoid-rich foods.\n\nOverall, the colorful feathers of parrots are a result of a complex interplay between genetic and environmental factors, which have evolved over time to provide these birds with an advantage in their natural habitats." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 449, 'prompt_tokens': 42, 'total_tokens': 491, 'completion_time': 0.706502112, 'completion_tokens_details': None, 'prompt_time': 0.007164694, 'prompt_tokens_details': None, 'queue_time': 0.163046899, 'total_time': 0.713666806}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e72df-6f69-7830-9d88-700445c2e1b8-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 449, 'total_tokens': 491}
# content='As of my cut-off knowledge in December 2023, the Prime Minister of India was Narendra Modi.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 40, 'total_tokens': 62, 'completion_time': 0.032061765, 'completion_tokens_details': None, 'prompt_time': 0.002308102, 'prompt_tokens_details': None, 'queue_time': 0.159565278, 'total_time': 0.034369867}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e72df-6f6c-71c0-8c7d-36a9b6bc2a21-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens':